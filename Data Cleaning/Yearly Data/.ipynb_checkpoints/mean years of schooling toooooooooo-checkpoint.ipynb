# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# # Mean years of schooling => 1980 to 2022

# %%
schooling_years_raw = pd.read_excel("Raw Data/Mean Years Of Schooling, Annual.xlsx", header = 9)
schooling_years_raw = schooling_years_raw.iloc[:4,:]
schooling_years_raw
# Out:
#                                           Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                                        Data Series      2022.0      2021.0
# 1          Mean Years Of Schooling (25 Years & Over)        11.7        11.6
# 2    Mean Years Of Schooling (25 Years & Over) - ...        12.1        12.0
# 3    Mean Years Of Schooling (25 Years & Over) - ...        11.3        11.3
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0      2020.0      2019.0      2018.0      2017.0      2016.0      2015.0
# 1        11.3        11.2        11.1        10.9        10.7        10.7
# 2        11.7        11.6        11.6        11.3        11.2        11.2
# 3        10.9        10.8        10.6        10.4        10.3        10.3
#
#    Unnamed: 9  ...  Unnamed: 32  Unnamed: 33  Unnamed: 34  Unnamed: 35  \
# 0      2014.0  ...       1991.0       1990.0       1989.0       1988.0
# ...

# %%
schooling_years_overall = (schooling_years_raw.iloc[:2,1:].T).iloc[::-1]
#schooling_years_overall.loc["Unnamed: 1", 0] = 5
schooling_years_overall.index = list(range(schooling_years_overall.shape[0]))
#schooling_years_raw
schooling_years_overall.columns = ['Year', 'Mean years of schooling for >25']
schooling_years_overall
# Out:
#       Year  Mean years of schooling for >25
# 0   1980.0                              4.7
# 1   1983.0                              5.6
# 2   1984.0                              5.8
# 3   1985.0                              5.7
# 4   1986.0                              5.8
# 5   1987.0                              5.9
# 6   1988.0                              6.2
# 7   1989.0                              6.3
# 8   1990.0                              6.6
# 9   1991.0                              6.9
# 10  1992.0                              7.1
# 11  1993.0                              7.2
# 12  1994.0                              7.3
# 13  1995.0                              7.7
# 14  1996.0                              7.7
# 15  1997.0                              7.9
# 16  1998.0                              8.1
# 17  1999.0                              8.2
# 18  2000.0                              8.6
# 19  2001.0                              8.5
# ...

# %%
schooling_years_overall.plot(x = "Year", y = "Mean years of schooling for >25", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
schooling_years_overall_all = (schooling_years_raw.iloc[:,1:].T).iloc[::-1]
schooling_years_overall_all.index = list(range(schooling_years_overall_all.shape[0]))
schooling_years_overall_all.columns = ['Year', 'Overall', "Males", "Females"]
schooling_years_overall_all["Year"] = pd.to_datetime(schooling_years_overall_all["Year"].astype(float), format="%Y")
schooling_years_overall_all
#Mean years of schooling for >25
# Out:
#          Year  Overall  Males  Females
# 0  1980-01-01      4.7    5.6      3.7
# 1  1983-01-01      5.6    6.4      4.7
# 2  1984-01-01      5.8    6.6      5.0
# 3  1985-01-01      5.7    6.5      4.9
# 4  1986-01-01      5.8    6.6      5.0
# 5  1987-01-01      5.9    6.6      5.2
# 6  1988-01-01      6.2    6.9      5.5
# 7  1989-01-01      6.3    7.0      5.6
# 8  1990-01-01      6.6    7.3      5.9
# 9  1991-01-01      6.9    7.6      6.2
# 10 1992-01-01      7.1    7.8      6.3
# 11 1993-01-01      7.2    7.9      6.5
# 12 1994-01-01      7.3    8.1      6.6
# 13 1995-01-01      7.7    8.4      7.2
# 14 1996-01-01      7.7    8.4      7.1
# 15 1997-01-01      7.9    8.6      7.2
# 16 1998-01-01      8.1    8.8      7.4
# 17 1999-01-01      8.2    8.8      7.6
# 18 2000-01-01      8.6    9.2      8.1
# 19 2001-01-01      8.5    9.2      7.9
# 20 2002-01-01      8.7    9.3      8.1
# 21 2003-01-01      8.8    9.4      8.2
# 22 2004-01-01      8.9    9.6      8.3
# ...

# %%
import matplotlib.pyplot as plt # we only need pyplot
schooling_years_overall_all.plot(x = "Year", y = ['Overall', "Males", "Females"], figsize=(10, 6))
plt.xlabel('Year')
plt.ylabel('Years (of schooling)')
plt.title("Mean years of schooling for >25")
#plt.xlabel('Year')
#plt.ylabel('Marriage Rate')
#plt.title('Male Marriage Rate')
plt.show()

# %%
schooling_years_overall_all.to_excel("Cleaned Data/Mean Years Of Schooling.xlsx")
