# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# # INFLATION RATE => 1962 to 2022 and 2023 jan
#
# * not inflation from previous month but from the previous year same month, so can see how the price has changed from previous year... so its more like annual inflation rate for each month? ...?????
# # * TO NOTE!!

# %%
inflation_rate_data = pd.read_excel("CPI change %, to get inflation rate, compared to same period previous year so no need adjust, better i think, monthly.xlsx", header=9)
#inflation_rate_data.rename(columns={'Data Series': 'year_Month'}, inplace=True)
inflation_rate_data.head()
# Out:
#                           Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                        Data Series  2023 Jan   2022 Dec   2022 Nov
# 1                          All Items        6.6        6.5        6.7
# 2                               Food        8.1        7.5        7.3
# 3    Food Excl Food Serving Services        7.2        7.1        6.7
# 4                    Bread & Cereals        7.8        7.2        6.2
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0  2022 Oct   2022 Sep   2022 Aug   2022 Jul   2022 Jun   2022 May   ...
# 1        6.7        7.5        7.5          7        6.7        5.6  ...
# 2        7.1        6.9        6.4        6.1        5.4        4.5  ...
# 3        6.8        6.8        6.3        6.1        5.6        4.5  ...
# 4          5          5        4.9        4.8          4        2.7  ...
#
#   Unnamed: 724 Unnamed: 725 Unnamed: 726 Unnamed: 727 Unnamed: 728  \
# ...

# %%
inflation_rate = inflation_rate_data.iloc[[0,1],1:]
# inflation_rate.set_index('year_Month', inplace=True)
# inflation_rate.rename(columns={'Data Series': 'year_Month'}, inplace = True)
inflation_rate.head()
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  2023 Jan   2022 Dec   2022 Nov   2022 Oct   2022 Sep   2022 Aug
# 1        6.6        6.5        6.7        6.7        7.5        7.5
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 724 Unnamed: 725  \
# 0  2022 Jul   2022 Jun   2022 May    2022 Apr   ...    1962 Oct     1962 Sep
# 1          7        6.7        5.6         5.4  ...            0          0.5
#
#   Unnamed: 726 Unnamed: 727 Unnamed: 728 Unnamed: 729 Unnamed: 730  \
# 0    1962 Aug     1962 Jul     1962 Jun     1962 May     1962 Apr
# 1         -0.4          0.9          0.9          1.1          0.5
#
#   Unnamed: 731 Unnamed: 732   Per Cent
# 0    1962 Mar     1962 Feb   1962 Jan
# 1         -0.7          0.9        0.4
#
# [2 rows x 733 columns]

# %%
inflation_rate_t = inflation_rate.T.iloc[::-1].copy()
inflation_rate_t.columns = ['year_Month', 'Inflation']
inflation_rate_t.index = list(range(733))
#_inflation_rate_t = inflation_rate_t.rename(columns={'Data Series': 'year_Month'})
inflation_rate_t
# Out:
#     year_Month Inflation
# 0    1962 Jan        0.4
# 1    1962 Feb        0.9
# 2    1962 Mar       -0.7
# 3    1962 Apr        0.5
# 4    1962 May        1.1
# ..         ...       ...
# 728  2022 Sep        7.5
# 729  2022 Oct        6.7
# 730  2022 Nov        6.7
# 731  2022 Dec        6.5
# 732  2023 Jan        6.6
#
# [733 rows x 2 columns]

# %%
# Amount of the Credit
f, axes = plt.subplots(1, 2, figsize=(18, 4))
sb.boxplot(data = inflation_rate_t['Inflation'], orient = "h", ax = axes[0])
sb.histplot(data = inflation_rate_t['Inflation'], ax = axes[1])
# Out:
# <AxesSubplot:xlabel='Inflation', ylabel='Count'>

# %%
inflation_rate_t['year_Month'] = pd.to_datetime(inflation_rate_t['year_Month'])
#raw_data['Mycol'] =  pd.to_datetime(raw_data['Mycol'], format='%d%b%Y:%H:%M:%S.%f')
inflation_rate_t
# Out:
#     year_Month Inflation
# 0   1962-01-01       0.4
# 1   1962-02-01       0.9
# 2   1962-03-01      -0.7
# 3   1962-04-01       0.5
# 4   1962-05-01       1.1
# ..         ...       ...
# 728 2022-09-01       7.5
# 729 2022-10-01       6.7
# 730 2022-11-01       6.7
# 731 2022-12-01       6.5
# 732 2023-01-01       6.6
#
# [733 rows x 2 columns]

# %%
inflation_rate_t.plot(x='year_Month', y='Inflation', figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='year_Month'>

# %% [markdown]
# Inflation rate roughly increasing throughout time, the outlier should clean or just mark as outlier

# %% [markdown]
# # INFANT DEATHS => 1960 to 2022
# * unsure if can make use cos infant death is part of live birth... isit? need double check

# %%
infant_death_no = pd.read_excel("infant death numbers, monthly.xlsx", header = 9)
infant_death_no.head()
# Out:
#                             Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                          Data Series  2022 Dec   2022 Nov   2022 Oct
# 1  Total Infant Deaths By Ethnic Group          9          7          4
# 2                               Malays          5          1          1
# 3                              Chinese          2          6          3
# 4                              Indians          0          0          0
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0  2022 Sep   2022 Aug   2022 Jul   2022 Jun   2022 May   2022 Apr   ...
# 1          7          7          5          9          5          4  ...
# 2          1          2          3          2          1          2  ...
# 3          5          4          2          6          2          0  ...
# 4          1          1          0          1          2          1  ...
#
#   Unnamed: 747 Unnamed: 748 Unnamed: 749 Unnamed: 750 Unnamed: 751  \
# ...

# %%
infant_death_no = infant_death_no.iloc[[0,1],1:]
infant_death_no.head()
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  2022 Dec   2022 Nov   2022 Oct   2022 Sep   2022 Aug   2022 Jul
# 1          9          7          4          7          7          5
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 747 Unnamed: 748  \
# 0  2022 Jun   2022 May   2022 Apr    2022 Mar   ...    1960 Oct     1960 Sep
# 1          9          5          4           8  ...          159          155
#
#   Unnamed: 749 Unnamed: 750 Unnamed: 751 Unnamed: 752 Unnamed: 753  \
# 0    1960 Aug     1960 Jul     1960 Jun     1960 May     1960 Apr
# 1          189          186          203          235          193
#
#   Unnamed: 754 Unnamed: 755     Number
# 0    1960 Mar     1960 Feb   1960 Jan
# 1          189          154        157
#
# [2 rows x 756 columns]

# %%
infant_death_no_t = infant_death_no.T.iloc[::-1].copy()
infant_death_no_t.columns = ["Data Series_monthly", "Total Infant Deaths"]
infant_death_no_t.index = list(range(756)) ##inflation_rate_t.index = list(range(733))
infant_death_no_t
# Out:
#     Data Series_monthly Total Infant Deaths
# 0             1960 Jan                  157
# 1             1960 Feb                  154
# 2             1960 Mar                  189
# 3             1960 Apr                  193
# 4             1960 May                  235
# ..                  ...                 ...
# 751           2022 Aug                    7
# 752           2022 Sep                    7
# 753           2022 Oct                    4
# 754           2022 Nov                    7
# 755           2022 Dec                    9
#
# [756 rows x 2 columns]

# %%
##inflation_rate_t['year_Month'] = pd.to_datetime(inflation_rate_t['year_Month'])
infant_death_no_t["Data Series_monthly"] = pd.to_datetime(infant_death_no_t["Data Series_monthly"])
infant_death_no_t
# Out:
#     Data Series_monthly Total Infant Deaths
# 0            1960-01-01                 157
# 1            1960-02-01                 154
# 2            1960-03-01                 189
# 3            1960-04-01                 193
# 4            1960-05-01                 235
# ..                  ...                 ...
# 751          2022-08-01                   7
# 752          2022-09-01                   7
# 753          2022-10-01                   4
# 754          2022-11-01                   7
# 755          2022-12-01                   9
#
# [756 rows x 2 columns]

# %%
## inflation_rate_t.plot(x='year_Month', y='Inflation')
infant_death_no_t.plot(x = "Data Series_monthly", y = "Total Infant Deaths", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Data Series_monthly'>

# %% [markdown]
# # LIVE BIRTHS? MOST IMPT? => 1960 to 2022

# %%
live_birth_data = pd.read_excel("Live-Births By Sex And Ethnic Group.xlsx", header = 9)
live_birth_data
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                         Data Series  2022 Dec   2022 Nov
# 1                   Total Live-Births By Ethnic Group       2887       2943
# 2                                              Malays        640        655
# 3                                             Chinese       1648       1659
# 4                                             Indians        319        355
# 5                                 Other Ethnic Groups        280        274
# 6              Total Male Live-Births By Ethnic Group       1465       1491
# 7                                              Malays        332        332
# 8                                             Chinese        823        862
# 9                                             Indians        161        173
# 10                                Other Ethnic Groups        149        124
# ...

# %%
live_birth_no = live_birth_data.iloc[[0,1],1:] ##infant_death_no = infant_death_no.iloc[[0,1],1:]
live_birth_no
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  2022 Dec   2022 Nov   2022 Oct   2022 Sep   2022 Aug   2022 Jul
# 1       2887       2943       3109       3272       3005       2962
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 747 Unnamed: 748  \
# 0  2022 Jun   2022 May   2022 Apr    2022 Mar   ...    1960 Oct     1960 Sep
# 1       2844       2989       2718        3128  ...         5752         5183
#
#   Unnamed: 749 Unnamed: 750 Unnamed: 751 Unnamed: 752 Unnamed: 753  \
# 0    1960 Aug     1960 Jul     1960 Jun     1960 May     1960 Apr
# 1         5331         5115         5178         5244         4904
#
#   Unnamed: 754 Unnamed: 755     Number
# 0    1960 Mar     1960 Feb   1960 Jan
# 1         4964         4596       4981
#
# [2 rows x 756 columns]

# %%
live_birth_no_t = live_birth_no.T.copy()
live_birth_no_t.columns = ["data_series_monthly", "live births no."] ##infant_death_no_t.columns = ["Data Series_monthly", "Total Infant Deaths"]
live_birth_no_t.index = list(range(756))
live_birth_no_t
# Out:
#     data_series_monthly live births no.
# 0             2022 Dec             2887
# 1             2022 Nov             2943
# 2             2022 Oct             3109
# 3             2022 Sep             3272
# 4             2022 Aug             3005
# ..                  ...             ...
# 751           1960 May             5244
# 752           1960 Apr             4904
# 753           1960 Mar             4964
# 754           1960 Feb             4596
# 755           1960 Jan             4981
#
# [756 rows x 2 columns]

# %%
live_birth_no_t["data_series_monthly"] = pd.to_datetime(live_birth_no_t["data_series_monthly"])
live_birth_no_t
# Out:
#     data_series_monthly live births no.
# 0            2022-12-01            2887
# 1            2022-11-01            2943
# 2            2022-10-01            3109
# 3            2022-09-01            3272
# 4            2022-08-01            3005
# ..                  ...             ...
# 751          1960-05-01            5244
# 752          1960-04-01            4904
# 753          1960-03-01            4964
# 754          1960-02-01            4596
# 755          1960-01-01            4981
#
# [756 rows x 2 columns]

# %%
live_birth_no_t.plot(x = "data_series_monthly", y = "live births no.", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='data_series_monthly'>

# %% [markdown]
# # NUMBER OF MARRIAGES PER MONTH? => 1961 to 2022

# %%
marriages_data_raw = pd.read_excel("no. of marriage per month also have!! but definitions have to get right, got civil etc, data need clean, monthly.xlsx", header = 9)
marriages_data_raw = marriages_data_raw.iloc[0:14,:]
marriages_data_raw
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0   Data Series      2022.0      2021.0      2020.0      2019.0      2018.0
# 1         Total     23368.0     22101.0     17124.0     19889.0     21308.0
# 2       January      1934.0      1711.0      1261.0      1717.0      1792.0
# 3      February      2067.0      1509.0      2041.0      1251.0      1307.0
# 4         March      1885.0      1792.0      1402.0      1724.0      1996.0
# 5         April      1257.0      1223.0       279.0      1011.0      1237.0
# 6           May      2072.0      1902.0       189.0      1703.0      1754.0
# 7          June      2114.0      1862.0      1423.0      1939.0      1969.0
# 8          July      1522.0      1581.0      1351.0      1463.0      1608.0
# 9        August      1138.0      1088.0      1265.0       953.0      1346.0
# 10    September      2211.0      2166.0      1272.0      2114.0      1967.0
# ...

# %%
marriage_annual = marriages_data_raw.iloc[[0,1],1:]
marriage_annual_t = marriage_annual.T.copy()
marriage_annual_t.columns = ["Year", "no. of marriages"]
marriage_annual_t.index = list(range(62))
marriage_annual_t["Year"] = pd.to_datetime(marriage_annual_t["Year"], format = '%Y')
marriage_annual_t
marriage_annual_t.plot(x = "Year", y = "no. of marriages", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
marriages_data = marriages_data_raw.drop([1])
marriages_data
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0   Data Series      2022.0      2021.0      2020.0      2019.0      2018.0
# 2       January      1934.0      1711.0      1261.0      1717.0      1792.0
# 3      February      2067.0      1509.0      2041.0      1251.0      1307.0
# 4         March      1885.0      1792.0      1402.0      1724.0      1996.0
# 5         April      1257.0      1223.0       279.0      1011.0      1237.0
# 6           May      2072.0      1902.0       189.0      1703.0      1754.0
# 7          June      2114.0      1862.0      1423.0      1939.0      1969.0
# 8          July      1522.0      1581.0      1351.0      1463.0      1608.0
# 9        August      1138.0      1088.0      1265.0       953.0      1346.0
# 10    September      2211.0      2166.0      1272.0      2114.0      1967.0
# 11      October      2024.0      2151.0      2230.0      1879.0      2048.0
# ...

# %%
marriages_data.index = list(range(13))
marriages_data
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0   Data Series      2022.0      2021.0      2020.0      2019.0      2018.0
# 1       January      1934.0      1711.0      1261.0      1717.0      1792.0
# 2      February      2067.0      1509.0      2041.0      1251.0      1307.0
# 3         March      1885.0      1792.0      1402.0      1724.0      1996.0
# 4         April      1257.0      1223.0       279.0      1011.0      1237.0
# 5           May      2072.0      1902.0       189.0      1703.0      1754.0
# 6          June      2114.0      1862.0      1423.0      1939.0      1969.0
# 7          July      1522.0      1581.0      1351.0      1463.0      1608.0
# 8        August      1138.0      1088.0      1265.0       953.0      1346.0
# 9     September      2211.0      2166.0      1272.0      2114.0      1967.0
# 10      October      2024.0      2151.0      2230.0      1879.0      2048.0
# ...

# %%
marriage_data_step1 = marriages_data.drop(0)
marriage_data_step1
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 1       January      1934.0      1711.0      1261.0      1717.0      1792.0
# 2      February      2067.0      1509.0      2041.0      1251.0      1307.0
# 3         March      1885.0      1792.0      1402.0      1724.0      1996.0
# 4         April      1257.0      1223.0       279.0      1011.0      1237.0
# 5           May      2072.0      1902.0       189.0      1703.0      1754.0
# 6          June      2114.0      1862.0      1423.0      1939.0      1969.0
# 7          July      1522.0      1581.0      1351.0      1463.0      1608.0
# 8        August      1138.0      1088.0      1265.0       953.0      1346.0
# 9     September      2211.0      2166.0      1272.0      2114.0      1967.0
# 10      October      2024.0      2151.0      2230.0      1879.0      2048.0
# 11     November      2445.0      2354.0      1892.0      2202.0      1938.0
# ...

# %%
print(marriage_data_step1.shape)
(marriage_data_step1.shape[1])-1
# Out:
# (12, 63)
# 62

# %%
marriage_data_step1.iloc[:,1]
# Out:
# 1     1934.0
# 2     2067.0
# 3     1885.0
# 4     1257.0
# 5     2072.0
# 6     2114.0
# 7     1522.0
# 8     1138.0
# 9     2211.0
# 10    2024.0
# 11    2445.0
# 12    2699.0
# Name: Unnamed: 1, dtype: float64

# %%
marriage_data_no = pd.DataFrame(marriage_data_step1.iloc[:,(marriage_data_step1.shape[1])-1])
marriage_data_no
# Out:
#     Number
# 1    281.0
# 2    197.0
# 3    191.0
# 4    357.0
# 5    249.0
# 6    321.0
# 7    191.0
# 8    176.0
# 9    327.0
# 10   316.0
# 11   463.0
# 12   595.0

# %%
marriage_data_no = pd.DataFrame(marriage_data_step1.iloc[:,(marriage_data_step1.shape[1])-1])
#j = 0
#list(range(60, 0, -1))
#for i in reversed(range((marriage_data_step1.shape[1])-1)[1:]):
for i in range(((marriage_data_step1.shape[1])-2),0 ,-1):
    #print(i)
    #marriage_data_no = pd.concat([marriage_data_no, pd.DataFrame(marriage_data_step1.iloc[:,i])])
    #print(pd.DataFrame(marriage_data_step1.iloc[:,i]))
    temp_marriage = (pd.DataFrame(marriage_data_step1.iloc[:,i])).set_axis(["Number"], axis = 1, inplace=False)
    #print(temp_marriage)
    marriage_data_no = pd.concat([marriage_data_no, temp_marriage])
    #j += 1
marriage_data_no
#print(j)
#print(list(range(((marriage_data_step1.shape[1])-2),0 ,-1)))
# Out:
#     Number
# 1    281.0
# 2    197.0
# 3    191.0
# 4    357.0
# 5    249.0
# ..     ...
# 8   1138.0
# 9   2211.0
# 10  2024.0
# 11  2445.0
# 12  2699.0
#
# [744 rows x 1 columns]

# %%
marriage_data_no.index = list(range(744))
marriage_data_no.columns = ["number of marriages"]
marriage_data_no
# Out:
#      number of marriages
# 0                  281.0
# 1                  197.0
# 2                  191.0
# 3                  357.0
# 4                  249.0
# ..                   ...
# 739               1138.0
# 740               2211.0
# 741               2024.0
# 742               2445.0
# 743               2699.0
#
# [744 rows x 1 columns]

# %%
datetime_try = pd.DataFrame({
    'year_month':pd.date_range(start='1961-01-01', periods=(62*12), freq="MS")
})
datetime_try
# Out:
#     year_month
# 0   1961-01-01
# 1   1961-02-01
# 2   1961-03-01
# 3   1961-04-01
# 4   1961-05-01
# ..         ...
# 739 2022-08-01
# 740 2022-09-01
# 741 2022-10-01
# 742 2022-11-01
# 743 2022-12-01
#
# [744 rows x 1 columns]

# %%
marriage_data_no_final = datetime_try.join(marriage_data_no)
marriage_data_no_final
# Out:
#     year_month  number of marriages
# 0   1961-01-01                281.0
# 1   1961-02-01                197.0
# 2   1961-03-01                191.0
# 3   1961-04-01                357.0
# 4   1961-05-01                249.0
# ..         ...                  ...
# 739 2022-08-01               1138.0
# 740 2022-09-01               2211.0
# 741 2022-10-01               2024.0
# 742 2022-11-01               2445.0
# 743 2022-12-01               2699.0
#
# [744 rows x 2 columns]

# %%
marriage_data_no_final.plot(x = "year_month", y = "number of marriages", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='year_month'>

# %%
## reiterate diff between annual and monthly
marriage_annual_t.plot(x = "Year", y = "no. of marriages", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
marriage_annual_t
# Out:
#          Year  no. of marriages
# 0  2022-01-01           23368.0
# 1  2021-01-01           22101.0
# 2  2020-01-01           17124.0
# 3  2019-01-01           19889.0
# 4  2018-01-01           21308.0
# ..        ...               ...
# 57 1965-01-01            7071.0
# 58 1964-01-01            6112.0
# 59 1963-01-01            5366.0
# 60 1962-01-01            4561.0
# 61 1961-01-01            3664.0
#
# [62 rows x 2 columns]

# %%
inflation_rate_t.to_excel("monthly 1962 to 2023 jan inflation rate from prev year same month data excel.xlsx")

# %%
infant_death_no_t.to_excel("monthly 1960 to 2022 infant death number data excel.xlsx")

# %%
##live_birth_no_t.to_excel("monthly 1960 to 2022 live birth number data excel.xlsx")

# %%
marriage_annual_t.to_excel("annual 1961 to 2022 marriage number data excel.xlsx")

# %%
marriage_data_no_final.to_excel("monthly 1961 to 2022 marriage number data excel.xlsx")
