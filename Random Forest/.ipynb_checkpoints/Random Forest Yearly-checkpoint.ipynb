# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
annual_combined_data = pd.read_excel("Yearly Data.xlsx", usecols=lambda x: 'Unnamed' not in x)
combined_changed_data_together_overall = pd.read_excel("Yearly Change Data.xlsx", usecols=lambda x: 'Unnamed' not in x)
combined_changed_data_together_overall_percent = pd.read_excel("Yearly % Change Data.xlsx", usecols=lambda x: 'Unnamed' not in x)

# %%
annual_live_birth = annual_combined_data.iloc[:, :2]
annual_live_birth
# Out:
#          Year  number of live_birth in the year
# 0  1960-01-01                             61775
# 1  1961-01-01                             59930
# 2  1962-01-01                             58977
# 3  1963-01-01                             59530
# 4  1964-01-01                             58217
# ..        ...                               ...
# 58 2018-01-01                             39039
# 59 2019-01-01                             39279
# 60 2020-01-01                             38590
# 61 2021-01-01                             38672
# 62 2022-01-01                             35724
#
# [63 rows x 2 columns]

# %%
live_birth_annual_change = pd.DataFrame(columns=["Year_Month", "Change in Live Birth"])
for i in range(1, annual_live_birth.shape[0]):
    if ((annual_live_birth.iloc[i, 1] - annual_live_birth.iloc[i-1, 1]) > 0):
        change = "INCREASE"
    else:
        change = "DECREASE"
    live_birth_annual_change.loc[i] = [annual_live_birth.iloc[i, 0], change]   
live_birth_annual_change
# Out:
#    Year_Month Change in Live Birth
# 1  1961-01-01             DECREASE
# 2  1962-01-01             DECREASE
# 3  1963-01-01             INCREASE
# 4  1964-01-01             DECREASE
# 5  1965-01-01             DECREASE
# ..        ...                  ...
# 58 2018-01-01             DECREASE
# 59 2019-01-01             INCREASE
# 60 2020-01-01             DECREASE
# 61 2021-01-01             INCREASE
# 62 2022-01-01             DECREASE
#
# [62 rows x 2 columns]

# %% [markdown]
# ## Random Forest Default Parameters (Raw Data)

# %%
# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# %%
annual_combined_data_temp = annual_combined_data.iloc[1:,:].copy()
annual_combined_data_temp.insert(1, live_birth_annual_change.columns[1], live_birth_annual_change.iloc[:, 1])

temp_X = annual_combined_data_temp.copy()
temp_X.replace([np.inf, -np.inf], np.nan, inplace=True)
temp_X.fillna(temp_X.mean(), inplace=True)
temp_X

y = annual_combined_data_temp["Change in Live Birth"]
X = pd.DataFrame(temp_X.drop(columns=["Year", "number of live_birth in the year", 'Change in Live Birth'], axis = 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

rf = RandomForestClassifier()
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn import tree
plt.figure(figsize=(30,30))
tree.plot_tree(rf.estimators_[0], rounded = True, filled = True, proportion = False, feature_names=X_train.columns, 
          class_names=["DECREASE","INCREASE"])
# Out:
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\602506722.py:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\602506722.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# Accuracy: 0.42105263157894735
# [Text(0.5555555555555556, 0.9166666666666666, 'Crude Marriage Rate <= 9.1\ngini = 0.439\nsamples = 30\nvalue = [29, 14]\nclass = DECREASE'),
#  Text(0.4444444444444444, 0.75, 'Female poly & uni 25_39 <= 58250.0\ngini = 0.361\nsamples = 26\nvalue = [29, 9]\nclass = DECREASE'),
#  Text(0.3333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = INCREASE'),
#  Text(0.5555555555555556, 0.5833333333333334, 'Number of brides (Total under 44) <= 21779.5\ngini = 0.313\nsamples = 24\nvalue = [29, 7]\nclass = DECREASE'),
#  Text(0.3333333333333333, 0.4166666666666667, 'Total Residents <= 2349732.5\ngini = 0.175\nsamples = 21\nvalue = [28, 3]\nclass = DECREASE'),
#  Text(0.2222222222222222, 0.25, 'Total Population (Number) <= 2077700.0\ngini = 0.42\nsamples = 8\nvalue = [7, 3]\nclass = DECREASE'),
#  Text(0.1111111111111111, 0.08333333333333333, 'gini = 0.0\nsamples = 5\nvalue = [7, 0]\nclass = DECREASE'),
#  Text(0.3333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = INCREASE'),
#  Text(0.4444444444444444, 0.25, 'gini = 0.0\nsamples = 13\nvalue = [21, 0]\nclass = DECREASE'),
#  Text(0.7777777777777778, 0.4166666666666667, 'Females average schooling years <= 8.951\ngini = 0.32\nsamples = 3\nvalue = [1, 4]\nclass = INCREASE'),
#  Text(0.6666666666666666, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = DECREASE'),
#  Text(0.8888888888888888, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]\nclass = INCREASE'),
#  Text(0.6666666666666666, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 5]\nclass = INCREASE')]

# %% [markdown]
# ## Random Forest Default Parameters (Change Data)

# %%
temp_X = combined_changed_data_together_overall.copy()
temp_X.replace([np.inf, -np.inf], np.nan, inplace=True)
temp_X.fillna(temp_X.mean(), inplace=True)
temp_X

y = annual_combined_data_temp["Change in Live Birth"]
X = pd.DataFrame(temp_X.drop(columns=["Year", "Change in Live Birth", 'Change in Live Birth Number'], axis = 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

rf = RandomForestClassifier()
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn import tree
plt.figure(figsize=(30,30))
tree.plot_tree(rf.estimators_[0], rounded = True, filled = True, proportion = False, feature_names=X_train.columns, 
          class_names=["DECREASE","INCREASE"])
# Out:
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\1259310915.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\1259310915.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# Accuracy: 0.6842105263157895
# [Text(0.5, 0.9166666666666666, 'Change in Total Brides Aged under 39 <= 1622.5\ngini = 0.357\nsamples = 27\nvalue = [33, 10]\nclass = DECREASE'),
#  Text(0.4, 0.75, 'Change in People with Minimum Education <= 41250.0\ngini = 0.26\nsamples = 23\nvalue = [33, 6]\nclass = DECREASE'),
#  Text(0.2, 0.5833333333333334, 'Change in Non-Resident Population <= 11709.0\ngini = 0.375\nsamples = 3\nvalue = [1, 3]\nclass = INCREASE'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = DECREASE'),
#  Text(0.3, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 3]\nclass = INCREASE'),
#  Text(0.6, 0.5833333333333334, 'Change in Residents Aged 20-39 <= -31957.0\ngini = 0.157\nsamples = 20\nvalue = [32, 3]\nclass = DECREASE'),
#  Text(0.5, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = INCREASE'),
#  Text(0.7, 0.4166666666666667, 'Change in Residents Aged 20-39 <= 31400.0\ngini = 0.111\nsamples = 19\nvalue = [32, 2]\nclass = DECREASE'),
#  Text(0.6, 0.25, 'gini = 0.0\nsamples = 14\nvalue = [26, 0]\nclass = DECREASE'),
#  Text(0.8, 0.25, 'Change in Fertility Rate <= -0.045\ngini = 0.375\nsamples = 5\nvalue = [6, 2]\nclass = DECREASE'),
#  Text(0.7, 0.08333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [6, 0]\nclass = DECREASE'),
#  Text(0.9, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = INCREASE'),
#  Text(0.6, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = INCREASE')]

# %% [markdown]
# ## Random Forest Default Parameters (% Change Data)

# %%
temp_X = combined_changed_data_together_overall_percent.copy()
temp_X.replace([np.inf, -np.inf], np.nan, inplace=True)
temp_X.fillna(temp_X.mean(), inplace=True)
temp_X

y = annual_combined_data_temp["Change in Live Birth"]
X = pd.DataFrame(temp_X.drop(columns=["Year", "Change in Live Birth", 'Change in Live Birth Number'], axis = 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

rf = RandomForestClassifier()
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn import tree
plt.figure(figsize=(30,30))
tree.plot_tree(rf.estimators_[0], rounded = True, filled = True, proportion = False, feature_names=X_train.columns, 
          class_names=["DECREASE","INCREASE"])
# Out:
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\1539072839.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\1539072839.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# Accuracy: 0.7368421052631579
# [Text(0.5454545454545454, 0.9166666666666666, 'Change in Total Brides Aged under 39 <= 0.087\ngini = 0.5\nsamples = 25\nvalue = [22, 21]\nclass = DECREASE'),
#  Text(0.36363636363636365, 0.75, 'Change in People with Minimum Education <= 0.021\ngini = 0.346\nsamples = 18\nvalue = [21, 6]\nclass = DECREASE'),
#  Text(0.2727272727272727, 0.5833333333333334, 'Changes in Total Brides <= 0.017\ngini = 0.457\nsamples = 11\nvalue = [11, 6]\nclass = DECREASE'),
#  Text(0.18181818181818182, 0.4166666666666667, "Change in Males' Average Schooling Years <= -0.003\ngini = 0.337\nsamples = 8\nvalue = [11, 3]\nclass = DECREASE"),
#  Text(0.09090909090909091, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = INCREASE'),
#  Text(0.2727272727272727, 0.25, 'Change in Non-Resident Population <= 0.044\ngini = 0.153\nsamples = 7\nvalue = [11, 1]\nclass = DECREASE'),
#  Text(0.18181818181818182, 0.08333333333333333, 'gini = 0.0\nsamples = 6\nvalue = [11, 0]\nclass = DECREASE'),
#  Text(0.36363636363636365, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = INCREASE'),
#  Text(0.36363636363636365, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = INCREASE'),
#  Text(0.45454545454545453, 0.5833333333333334, 'gini = 0.0\nsamples = 7\nvalue = [10, 0]\nclass = DECREASE'),
#  Text(0.7272727272727273, 0.75, 'Change in Unemployment Rate <= -0.017\ngini = 0.117\nsamples = 7\nvalue = [1, 15]\nclass = INCREASE'),
#  Text(0.6363636363636364, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 5]\nclass = INCREASE'),
#  Text(0.8181818181818182, 0.5833333333333334, 'Change in Fertility Rate <= -0.054\ngini = 0.165\nsamples = 5\nvalue = [1, 10]\nclass = INCREASE'),
#  Text(0.7272727272727273, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = DECREASE'),
#  Text(0.9090909090909091, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 10]\nclass = INCREASE')]

# %% [markdown]
# ## Random Forest Selected Hyperparameters (Raw Data)

# %%
annual_combined_data_temp = annual_combined_data.iloc[1:,:].copy()
annual_combined_data_temp.insert(1, live_birth_annual_change.columns[1], live_birth_annual_change.iloc[:, 1])

temp_X = annual_combined_data_temp.copy()
temp_X.replace([np.inf, -np.inf], np.nan, inplace=True)
temp_X.fillna(temp_X.mean(), inplace=True)
temp_X

y = annual_combined_data_temp["Change in Live Birth"]
X = pd.DataFrame(temp_X.drop(columns=["Year", "number of live_birth in the year", 'Change in Live Birth'], axis = 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

rf = RandomForestClassifier(n_estimators=1000, max_depth=3, max_features=((X.shape[1]//2)+1), bootstrap=True, max_samples=(X_train.shape[0]//2))
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn import tree
plt.figure(figsize=(30,30))
tree.plot_tree(rf.estimators_[0], rounded = True, filled = True, proportion = False, feature_names=X_train.columns, 
          class_names=["DECREASE","INCREASE"])
# Out:
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\198055316.py:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\198055316.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# Accuracy: 0.631578947368421
# [Text(0.6666666666666666, 0.875, 'Male Marriage Rate <= 55.75\ngini = 0.444\nsamples = 14\nvalue = [14, 7]\nclass = DECREASE'),
#  Text(0.5, 0.625, 'Female poly & uni 25_39 <= 374600.0\ngini = 0.219\nsamples = 12\nvalue = [14, 2]\nclass = DECREASE'),
#  Text(0.3333333333333333, 0.375, 'Permanent Resident Population (Number) <= 530366.0\ngini = 0.124\nsamples = 11\nvalue = [14, 1]\nclass = DECREASE'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 9\nvalue = [13, 0]\nclass = DECREASE'),
#  Text(0.5, 0.125, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = DECREASE'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = INCREASE'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 5]\nclass = INCREASE')]

# %% [markdown]
# ## Random Forest Selected Hyperparameters (Change Data)

# %%
temp_X = combined_changed_data_together_overall.copy()
temp_X.replace([np.inf, -np.inf], np.nan, inplace=True)
temp_X.fillna(temp_X.mean(), inplace=True)
temp_X

y = annual_combined_data_temp["Change in Live Birth"]
X = pd.DataFrame(temp_X.drop(columns=["Year", "Change in Live Birth", 'Change in Live Birth Number'], axis = 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

rf = RandomForestClassifier(n_estimators=1000, max_depth=3, max_features=((X.shape[1]//2)+1), bootstrap=True, max_samples=(X_train.shape[0]//2))
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn import tree
plt.figure(figsize=(30,30))
tree.plot_tree(rf.estimators_[0], rounded = True, filled = True, proportion = False, feature_names=X_train.columns, 
          class_names=["DECREASE","INCREASE"])
# Out:
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\2849613346.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\2849613346.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# Accuracy: 0.7894736842105263
# [Text(0.6, 0.875, 'Change in Fertility Rate <= -0.005\ngini = 0.444\nsamples = 18\nvalue = [14, 7]\nclass = DECREASE'),
#  Text(0.4, 0.625, 'Change in Total Brides Aged under 39 <= 1181.5\ngini = 0.219\nsamples = 13\nvalue = [14, 2]\nclass = DECREASE'),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 10\nvalue = [12, 0]\nclass = DECREASE'),
#  Text(0.6, 0.375, 'Changes in Total Brides <= 2242.5\ngini = 0.5\nsamples = 3\nvalue = [2, 2]\nclass = DECREASE'),
#  Text(0.4, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]\nclass = INCREASE'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = DECREASE'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = INCREASE')]

# %% [markdown]
# ## Random Forest Selected Hyperparameters (% Change Data)

# %%
temp_X = combined_changed_data_together_overall_percent.copy()
temp_X.replace([np.inf, -np.inf], np.nan, inplace=True)
temp_X.fillna(temp_X.mean(), inplace=True)
temp_X

y = annual_combined_data_temp["Change in Live Birth"]
X = pd.DataFrame(temp_X.drop(columns=["Year", "Change in Live Birth", 'Change in Live Birth Number'], axis = 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

rf = RandomForestClassifier(n_estimators=1000, max_depth=3, max_features=((X.shape[1]//2)+1), bootstrap=True, max_samples=(X_train.shape[0]//2))
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn import tree
plt.figure(figsize=(30,30))
tree.plot_tree(rf.estimators_[0], rounded = True, filled = True, proportion = False, feature_names=X_train.columns, 
          class_names=["DECREASE","INCREASE"])
# Out:
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\3389792064.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\3389792064.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# Accuracy: 0.8421052631578947
# [Text(0.4, 0.875, 'Change in Fertility Rate <= -0.028\ngini = 0.49\nsamples = 15\nvalue = [12, 9]\nclass = DECREASE'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [10, 0]\nclass = DECREASE'),
#  Text(0.6, 0.625, 'Change in Permanent Resident Population <= 0.079\ngini = 0.298\nsamples = 10\nvalue = [2, 9]\nclass = INCREASE'),
#  Text(0.4, 0.375, 'Change in Average Full-Time Working Hours per Week <= -0.003\ngini = 0.18\nsamples = 9\nvalue = [1, 9]\nclass = INCREASE'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [0, 9]\nclass = INCREASE'),
#  Text(0.6, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = DECREASE'),
#  Text(0.8, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = DECREASE')]

# %% [markdown]
# ## Random Forest GridSearch CV (Raw Data)

# %%
annual_combined_data_temp = annual_combined_data.iloc[1:,:].copy()
annual_combined_data_temp.insert(1, live_birth_annual_change.columns[1], live_birth_annual_change.iloc[:, 1])

temp_X = annual_combined_data_temp.copy()
temp_X.replace([np.inf, -np.inf], np.nan, inplace=True)
temp_X.fillna(temp_X.mean(), inplace=True)
temp_X

y = annual_combined_data_temp["Change in Live Birth"]
X = pd.DataFrame(temp_X.drop(columns=["Year", "number of live_birth in the year", 'Change in Live Birth'], axis = 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

from sklearn.model_selection import GridSearchCV

no_features = X.shape[1]

param = {'max_depth': [3,5,6,9, None], 
         'n_estimators':[50, 70, 100, 150, 200], 
          #'bootstrap':[True, False],
            'max_features':[no_features, no_features//2, no_features//3],
                'bootstrap':[True, False]}

grid_model = GridSearchCV(RandomForestClassifier(),param_grid=param 
                     , cv=3) ## 3 for annual, due to no. of data points?



grid_model.fit(X_train,y_train)
print(grid_model.best_score_)
print(grid_model.best_params_)
# Out:
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\3415153724.py:6: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\3415153724.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# 0.7000000000000001
# {'bootstrap': True, 'max_depth': None, 'max_features': 27, 'n_estimators': 150}

# %% [markdown]
# ## Random Forest GridSearch CV (Change Data)

# %%
temp_X = combined_changed_data_together_overall.copy()
temp_X.replace([np.inf, -np.inf], np.nan, inplace=True)
temp_X.fillna(temp_X.mean(), inplace=True)
temp_X

y = annual_combined_data_temp["Change in Live Birth"]
X = pd.DataFrame(temp_X.drop(columns=["Year", "Change in Live Birth", 'Change in Live Birth Number'], axis = 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

from sklearn.model_selection import GridSearchCV

no_features = X.shape[1]

param = {'max_depth': [3,5,6,9, None], 
         'n_estimators':[50, 70, 100, 150, 200], 
          #'bootstrap':[True, False],
            'max_features':[no_features, no_features//2, no_features//3],
                'bootstrap':[True, False]}

grid_model = GridSearchCV(RandomForestClassifier(),param_grid=param 
                     , cv=3) ## 3 for annual, due to no. of data points?



grid_model.fit(X_train,y_train)
print(grid_model.best_score_)
print(grid_model.best_params_)
# Out:
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\589055020.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\589055020.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# 0.9095238095238095
# {'bootstrap': False, 'max_depth': 3, 'max_features': 13, 'n_estimators': 150}

# %% [markdown]
# ## Random Forest GridSearch CV (% Change Data)

# %%
temp_X = combined_changed_data_together_overall_percent.copy()
temp_X.replace([np.inf, -np.inf], np.nan, inplace=True)
temp_X.fillna(temp_X.mean(), inplace=True)
temp_X

y = annual_combined_data_temp["Change in Live Birth"]
X = pd.DataFrame(temp_X.drop(columns=["Year", "Change in Live Birth", 'Change in Live Birth Number'], axis = 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

from sklearn.model_selection import GridSearchCV

no_features = X.shape[1]

param = {'max_depth': [3,5,6,9, None], 
         'n_estimators':[50, 70, 100, 150, 200], 
          #'bootstrap':[True, False],
            'max_features':[no_features, no_features//2, no_features//3],
                'bootstrap':[True, False]}

grid_model = GridSearchCV(RandomForestClassifier(),param_grid=param 
                     , cv=3) ## 3 for annual, due to no. of data points?



grid_model.fit(X_train,y_train)
print(grid_model.best_score_)
print(grid_model.best_params_)
# Out:
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\3719352175.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# C:\Users\Audric Ho\AppData\Local\Temp\ipykernel_43472\3719352175.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_X.fillna(temp_X.mean(), inplace=True)
# 0.9079365079365079
# {'bootstrap': True, 'max_depth': 6, 'max_features': 27, 'n_estimators': 50}
