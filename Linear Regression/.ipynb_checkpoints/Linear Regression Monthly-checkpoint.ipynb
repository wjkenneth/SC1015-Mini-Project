# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
combined_data_together_overall = pd.read_excel("Monthly Data.xlsx", usecols=lambda x: 'Unnamed' not in x)

# %%
X_all = combined_data_together_overall[["Total Infant Deaths", "number of marriages", "CPI values(seasonally adjusted)", "CPI values(non-seasonally adjusted)", "Inflation(CPI % change from previous month, seasonally adjusted)", "Inflation(CPI % change from previous month, non-seasonally adjusted)", "Resale House Avg Price", "Resale Houses Sold"]]
y_original = combined_data_together_overall['live births no.']


for column in X_all:
    print(column)
    x = X_all[column]
    y = y_original.copy()
    mask = ~np.isnan(x) & ~np.isnan(y)
    
    x = pd.DataFrame(x[mask])
    y = pd.DataFrame(y_original[mask])
    
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
    
    linreg = linear_model.LinearRegression()
    linreg.fit(x_train, y_train)
    
    y_train_pred = linreg.predict(x_train)
    y_test_pred = linreg.predict(x_test)
    
    # Plot linear regression line for both train and test data, using data from train data to get linear regression line
    f, axes = plt.subplots(1, 2, figsize=(24, 12))
    axes[0].scatter(x_train, y_train, color = "b")
    axes[0].scatter(x_train, y_train_pred, color = "r")
    ## axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
    axes[0].set_xlabel(f"{column} (Train)")
    axes[0].set_ylabel("live births no. (Train)")
    axes[1].scatter(x_test, y_test, color = "b")
    axes[1].scatter(x_test, y_test_pred, color = "g")
    axes[1].set_xlabel(f"{column} (Test)")
    axes[1].set_ylabel("live births no. (Test)")
    # Coefficients of the Linear Regression line
    print('Intercept of Regression \t: b = ', linreg.intercept_)
    print('Coefficients of Regression \t: a = ', linreg.coef_)
    print()
    # Check the Goodness of Fit (on Train Data)
    print("Goodness of Fit of Model \tTrain Dataset")
    print("Explained Variance (R^2) \t:", linreg.score(x_train, y_train))
    print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
    print()
    # Check the Goodness of Fit (on Test Data)
    print("Goodness of Fit of Model \tTest Dataset")
    print("Explained Variance (R^2) \t:", linreg.score(x_test, y_test))
    print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
    print()
    print(f"RMSE of test data = {np.sqrt(mean_squared_error(y_test, y_test_pred))}")
    print()
    print()
# Out:
# Total Infant Deaths
# Intercept of Regression 	: b =  [3340.93189716]
# Coefficients of Regression 	: a =  [[9.30655856]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.49919448501134234
# Mean Squared Error (MSE) 	: 175595.95211202512
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5589087521688929
# Mean Squared Error (MSE) 	: 159402.3508580562
#
# RMSE of test data = 399.25223964062644
#
#
# number of marriages
# Intercept of Regression 	: b =  [4304.3479468]
# Coefficients of Regression 	: a =  [[-0.40258271]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.15247616553335364
# Mean Squared Error (MSE) 	: 281005.8785079427
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.09984249629896602
# Mean Squared Error (MSE) 	: 262487.34110066213
#
# RMSE of test data = 512.3351843282502
#
#
# CPI values(seasonally adjusted)
# Intercept of Regression 	: b =  [4506.16383189]
# ...

# %% [markdown]
# ## The variables against live birth numbers
# ### Metrics obtained
#
# - For Total Infant Deaths, after running the data set until satisfactory values
#
# > * Intercept of Regression 	: b =  [3340.93189716]
# > * Coefficients of Regression 	: a =  [[9.30655856]]
# >
# >
# > * Goodness of Fit of Model 	Train Dataset
# > * Explained Variance (R^2) 	: 0.49919448501134234
# > * Mean Squared Error (MSE) 	: 175595.95211202512
# >
# >
# > * Goodness of Fit of Model 	Test Dataset
# > * Explained Variance (R^2) 	: 0.5589087521688929
# > * Mean Squared Error (MSE) 	: 159402.3508580562
# >
# >
# > * RMSE of test data = 399.25223964062644
#
#
# - For number of marriages, after running the data set until satisfactory values
#
# > * Intercept of Regression 	: b =  [4304.3479468]
# > * Coefficients of Regression 	: a =  [[-0.40258271]]
# >
# >
# > * Goodness of Fit of Model 	Train Dataset
# > * Explained Variance (R^2) 	: 0.15247616553335364
# > * Mean Squared Error (MSE) 	: 281005.8785079427
# >
# >
# > * Goodness of Fit of Model 	Test Dataset
# > * Explained Variance (R^2) 	: 0.09984249629896602
# > * Mean Squared Error (MSE) 	: 262487.34110066213
# >
# >
# > * RMSE of test data = 512.3351843282502
#
# - For CPI values(seasonally adjusted), after running the data set until satisfactory values
#
# > * Intercept of Regression 	: b =  [4506.16383189]
# > * Coefficients of Regression 	: a =  [[-12.55644911]]
# >
# >
# > * Goodness of Fit of Model 	Train Dataset
# > * Explained Variance (R^2) 	: 0.3038025780187944
# > * Mean Squared Error (MSE) 	: 231069.93763205924
# >
# >
# > * Goodness of Fit of Model 	Test Dataset
# > * Explained Variance (R^2) 	: 0.33447570450676856
# > * Mean Squared Error (MSE) 	: 193212.38056822677
# >
# >
# > * RMSE of test data = 439.5593026751075
#
# - For CPI values(non-seasonally adjusted), after running the data set until satisfactory values
#
# > * Intercept of Regression 	: b =  [4491.110821]
# > * Coefficients of Regression 	: a =  [[-12.46514781]]
# >
# >
# > * Goodness of Fit of Model 	Train Dataset
# > * Explained Variance (R^2) 	: 0.302889569177895
# > * Mean Squared Error (MSE) 	: 229153.44198644947
# >
# >
# > * Goodness of Fit of Model 	Test Dataset
# > * Explained Variance (R^2) 	: 0.3440184323137645
# > * Mean Squared Error (MSE) 	: 200315.22392940504
# >
# >
# > * RMSE of test data = 447.5658878080467
#
# - For Inflation(CPI % change from previous month, seasonally adjusted), after running the data set until satisfactory values
#
# > * Intercept of Regression 	: b =  [3701.23857672]
# > * Coefficients of Regression 	: a =  [[2493.38394785]]
# >
# >
# > * Goodness of Fit of Model 	Train Dataset
# > * Explained Variance (R^2) 	: 0.0007574931328057088
# > * Mean Squared Error (MSE) 	: 322529.32352728705
# >
# >
# > * Goodness of Fit of Model 	Test Dataset
# > * Explained Variance (R^2) 	: -0.002793136948886943
# > * Mean Squared Error (MSE) 	: 320367.1812781094
# >
# >
# > * RMSE of test data = 566.0098773679744
#
# - For Inflation(CPI % change from previous month, non-seasonally adjusted), after running the data set until satisfactory values
#
# > * Intercept of Regression 	: b =  [3700.965615]
# > * Coefficients of Regression 	: a =  [[2762.76561956]]
# >
# >
# > * Goodness of Fit of Model 	Train Dataset
# > * Explained Variance (R^2) 	: 0.001130073765286066
# > * Mean Squared Error (MSE) 	: 326472.9880881343
# >
# >
# > * Goodness of Fit of Model 	Test Dataset
# > * Explained Variance (R^2) 	: -0.009116387485809563
# > * Mean Squared Error (MSE) 	: 305927.26850548724
# >
# >
# > * RMSE of test data = 553.1069232123996
#
# - For Resale House Avg Price, after running the data set until satisfactory values
#
# > * Intercept of Regression 	: b =  [4059.83161644]
# > * Coefficients of Regression 	: a =  [[-0.00175905]]
# >
# >
# > * Goodness of Fit of Model 	Train Dataset
# > * Explained Variance (R^2) 	: 0.2736719658428991
# > * Mean Squared Error (MSE) 	: 135628.10285725386
# >
# >
# > * Goodness of Fit of Model 	Test Dataset
# > * Explained Variance (R^2) 	: 0.31983037800524183
# > * Mean Squared Error (MSE) 	: 136444.34034301082
# >
# >
# > * RMSE of test data = 369.38373047957975
#
# - For Resale Houses Sold, after running the data set until satisfactory values
#
# > * Intercept of Regression 	: b =  [3617.54228315]
# > * Coefficients of Regression 	: a =  [[-0.03821423]]
# >
# >
# > * Goodness of Fit of Model 	Train Dataset
# > * Explained Variance (R^2) 	: 0.006741513041615299
# > * Mean Squared Error (MSE) 	: 182482.9069633169
# >
# >
# > * Goodness of Fit of Model 	Test Dataset
# > * Explained Variance (R^2) 	: -0.009922623124154262
# > * Mean Squared Error (MSE) 	: 218510.6016070635
# >
# >
# > * RMSE of test data = 467.4511756398346

# %% [markdown]
# ### Based on the MSE and RMSE for predicted being high, the low R^2 explained variance and some even being negative, such as inflation rate, which means that the model used, this linear regression is a worse fit compared to the horizontal, and the graph visuals
#
# ### Thus, we have decided that linear regression is not a good model and choice and for predicting the future live birth numbers
#
# ### As such, classification of whether the live birth numbers will be better, especially when we are to consider the limited data points that some data have and especially so for the annual data, which will make the linear regression even less effective.
#
# ### Hence, classification of whether the live birth numbers will increase or decrease will be the focus of this project

# %% [markdown]
# ### However, we will still take note of the variables with high correlation to the live birth numbers, such as CPI values and Resale House Avg Price. Although their correlation is not very high, it has more datapoints which would be more reliable and telling compared to the annual data. As such, we will accept this lower correlation here and will set the benchmark for correlation to be higher when picking variables from the annual data variables

# %% [markdown]
# ### Infant death has a high correlation, it can definitely help in prediciting the live birth numbers may not be a factor that will cause and affect the live birth number. As such, it may not be a variable we choose at the end as it may not cause a low live birth number

# %% [markdown]
# > * CPI values(either adjustment) => -0.56
# > * Resale House Avg Price => -0.54
#
# > * Total Infant Deaths => 0.72 // but may not be a cause of the low live birth number!, but in fact be a "symptom" of the low live birth number
